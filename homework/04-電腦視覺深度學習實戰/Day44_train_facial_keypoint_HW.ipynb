# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = '/content/drive/My Drive/AI/1st-DL-CVMarathon/data/facial-keypoints-detection/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0059 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00221, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00221 to 0.00194, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00194 to 0.00184, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00184
# Epoch 5/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00184 to 0.00178, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 9.5042e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00178 to 0.00171, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 8.1417e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00171 to 0.00153, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 6.9029e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00153 to 0.00141, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 6.2284e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00141 to 0.00130, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 5.8509e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00130 to 0.00116, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 5.1318e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00116 to 0.00109, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 4.6578e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00109 to 0.00106, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 4.4249e-04 - val_loss: 9.7220e-04
#
# Epoch 00013: val_loss improved from 0.00106 to 0.00097, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 4.1070e-04 - val_loss: 9.2771e-04
#
# Epoch 00014: val_loss improved from 0.00097 to 0.00093, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 3.9141e-04 - val_loss: 9.1922e-04
#
# Epoch 00015: val_loss improved from 0.00093 to 0.00092, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 3.7464e-04 - val_loss: 8.5776e-04
#
# Epoch 00016: val_loss improved from 0.00092 to 0.00086, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 3.4319e-04 - val_loss: 8.7096e-04
#
# Epoch 00017: val_loss did not improve from 0.00086
# Epoch 18/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 3.2942e-04 - val_loss: 8.8164e-04
#
# Epoch 00018: val_loss did not improve from 0.00086
# Epoch 19/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 3.1655e-04 - val_loss: 8.4388e-04
#
# Epoch 00019: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 3.0370e-04 - val_loss: 8.0705e-04
#
# Epoch 00020: val_loss improved from 0.00084 to 0.00081, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 2.9483e-04 - val_loss: 8.4370e-04
#
# Epoch 00021: val_loss did not improve from 0.00081
# Epoch 22/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 2.8667e-04 - val_loss: 8.0088e-04
#
# Epoch 00022: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 2.7906e-04 - val_loss: 8.0664e-04
#
# Epoch 00023: val_loss did not improve from 0.00080
# Epoch 24/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 2.6962e-04 - val_loss: 7.8584e-04
#
# Epoch 00024: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.6652e-04 - val_loss: 8.0144e-04
#
# Epoch 00025: val_loss did not improve from 0.00079
# Epoch 26/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 2.5484e-04 - val_loss: 7.8103e-04
#
# Epoch 00026: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 2.5075e-04 - val_loss: 8.1221e-04
#
# Epoch 00027: val_loss did not improve from 0.00078
# Epoch 28/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 2.4572e-04 - val_loss: 7.4978e-04
#
# Epoch 00028: val_loss improved from 0.00078 to 0.00075, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 2.3967e-04 - val_loss: 7.4843e-04
#
# Epoch 00029: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 2.3574e-04 - val_loss: 7.5177e-04
#
# Epoch 00030: val_loss did not improve from 0.00075
# Epoch 31/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 2.2816e-04 - val_loss: 7.4389e-04
#
# Epoch 00031: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 2.2949e-04 - val_loss: 7.4034e-04
#
# Epoch 00032: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.2432e-04 - val_loss: 7.6965e-04
#
# Epoch 00033: val_loss did not improve from 0.00074
# Epoch 34/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 2.2225e-04 - val_loss: 7.4611e-04
#
# Epoch 00034: val_loss did not improve from 0.00074
# Epoch 35/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 2.1161e-04 - val_loss: 7.4536e-04
#
# Epoch 00035: val_loss did not improve from 0.00074
# Epoch 36/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.0998e-04 - val_loss: 7.2857e-04
#
# Epoch 00036: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 2.1395e-04 - val_loss: 7.4296e-04
#
# Epoch 00037: val_loss did not improve from 0.00073
# Epoch 38/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 2.0086e-04 - val_loss: 7.2662e-04
#
# Epoch 00038: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.9228e-04 - val_loss: 7.7955e-04
#
# Epoch 00039: val_loss did not improve from 0.00073
# Epoch 40/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 1.9791e-04 - val_loss: 7.3985e-04
#
# Epoch 00040: val_loss did not improve from 0.00073
# Epoch 41/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 1.9536e-04 - val_loss: 7.3691e-04
#
# Epoch 00041: val_loss did not improve from 0.00073
# Epoch 42/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.9516e-04 - val_loss: 7.0048e-04
#
# Epoch 00042: val_loss improved from 0.00073 to 0.00070, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.8688e-04 - val_loss: 7.2377e-04
#
# Epoch 00043: val_loss did not improve from 0.00070
# Epoch 44/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.8052e-04 - val_loss: 7.3293e-04
#
# Epoch 00044: val_loss did not improve from 0.00070
# Epoch 45/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.7945e-04 - val_loss: 7.9999e-04
#
# Epoch 00045: val_loss did not improve from 0.00070
# Epoch 46/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 1.8264e-04 - val_loss: 7.3883e-04
#
# Epoch 00046: val_loss did not improve from 0.00070
# Epoch 47/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.7720e-04 - val_loss: 7.3724e-04
#
# Epoch 00047: val_loss did not improve from 0.00070
# Epoch 48/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 1.8286e-04 - val_loss: 7.2146e-04
#
# Epoch 00048: val_loss did not improve from 0.00070
# Epoch 49/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.7445e-04 - val_loss: 7.8426e-04
#
# Epoch 00049: val_loss did not improve from 0.00070
# Epoch 50/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 1.7561e-04 - val_loss: 7.7013e-04
#
# Epoch 00050: val_loss did not improve from 0.00070
# Epoch 51/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 1.7191e-04 - val_loss: 7.3659e-04
#
# Epoch 00051: val_loss did not improve from 0.00070
# Epoch 52/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 1.6647e-04 - val_loss: 7.0202e-04
#
# Epoch 00052: val_loss did not improve from 0.00070
# Epoch 53/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.6319e-04 - val_loss: 7.2458e-04
#
# Epoch 00053: val_loss did not improve from 0.00070
# Epoch 54/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.6485e-04 - val_loss: 7.1753e-04
#
# Epoch 00054: val_loss did not improve from 0.00070
# Epoch 55/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.6098e-04 - val_loss: 7.0390e-04
#
# Epoch 00055: val_loss did not improve from 0.00070
# Epoch 56/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.6091e-04 - val_loss: 7.0213e-04
#
# Epoch 00056: val_loss did not improve from 0.00070
# Epoch 57/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.6316e-04 - val_loss: 7.6408e-04
#
# Epoch 00057: val_loss did not improve from 0.00070
# Epoch 58/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.5807e-04 - val_loss: 7.2247e-04
#
# Epoch 00058: val_loss did not improve from 0.00070
# Epoch 59/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 1.5685e-04 - val_loss: 7.1027e-04
#
# Epoch 00059: val_loss did not improve from 0.00070
# Epoch 60/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.5271e-04 - val_loss: 7.4686e-04
#
# Epoch 00060: val_loss did not improve from 0.00070
# Epoch 61/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 1.5184e-04 - val_loss: 7.2878e-04
#
# Epoch 00061: val_loss did not improve from 0.00070
# Epoch 62/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 1.4666e-04 - val_loss: 7.3616e-04
#
# Epoch 00062: val_loss did not improve from 0.00070
# Epoch 63/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.4414e-04 - val_loss: 7.1797e-04
#
# Epoch 00063: val_loss did not improve from 0.00070
# Epoch 64/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 1.5056e-04 - val_loss: 7.1741e-04
#
# Epoch 00064: val_loss did not improve from 0.00070
# Epoch 65/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.4405e-04 - val_loss: 7.3551e-04
#
# Epoch 00065: val_loss did not improve from 0.00070
# Epoch 66/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.4525e-04 - val_loss: 7.2242e-04
#
# Epoch 00066: val_loss did not improve from 0.00070
# Epoch 67/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.4400e-04 - val_loss: 7.7416e-04
#
# Epoch 00067: val_loss did not improve from 0.00070
# Epoch 68/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.4105e-04 - val_loss: 7.2860e-04
#
# Epoch 00068: val_loss did not improve from 0.00070
# Epoch 69/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.4082e-04 - val_loss: 6.9892e-04
#
# Epoch 00069: val_loss improved from 0.00070 to 0.00070, saving model to best_weights.h5
# Epoch 70/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.3929e-04 - val_loss: 7.4381e-04
#
# Epoch 00070: val_loss did not improve from 0.00070
# Epoch 71/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.3866e-04 - val_loss: 7.5607e-04
#
# Epoch 00071: val_loss did not improve from 0.00070
# Epoch 72/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.3779e-04 - val_loss: 7.1999e-04
#
# Epoch 00072: val_loss did not improve from 0.00070
# Epoch 73/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.4444e-04 - val_loss: 7.4803e-04
#
# Epoch 00073: val_loss did not improve from 0.00070
# Epoch 74/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.4167e-04 - val_loss: 7.1004e-04
#
# Epoch 00074: val_loss did not improve from 0.00070
# Epoch 75/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 1.3573e-04 - val_loss: 7.1919e-04
#
# Epoch 00075: val_loss did not improve from 0.00070
# Epoch 76/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 1.3733e-04 - val_loss: 7.3010e-04
#
# Epoch 00076: val_loss did not improve from 0.00070
# Epoch 77/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.3126e-04 - val_loss: 7.3554e-04
#
# Epoch 00077: val_loss did not improve from 0.00070
# Epoch 78/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 1.3163e-04 - val_loss: 7.1987e-04
#
# Epoch 00078: val_loss did not improve from 0.00070
# Epoch 79/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 1.2746e-04 - val_loss: 7.5936e-04
#
# Epoch 00079: val_loss did not improve from 0.00070
# Epoch 80/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.3193e-04 - val_loss: 7.3596e-04
#
# Epoch 00080: val_loss did not improve from 0.00070
# Epoch 81/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.2596e-04 - val_loss: 7.1068e-04
#
# Epoch 00081: val_loss did not improve from 0.00070
# Epoch 82/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 1.2381e-04 - val_loss: 7.5323e-04
#
# Epoch 00082: val_loss did not improve from 0.00070
# Epoch 83/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.2406e-04 - val_loss: 7.3311e-04
#
# Epoch 00083: val_loss did not improve from 0.00070
# Epoch 84/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.2631e-04 - val_loss: 7.4920e-04
#
# Epoch 00084: val_loss did not improve from 0.00070
# Epoch 85/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.1844e-04 - val_loss: 7.2007e-04
#
# Epoch 00085: val_loss did not improve from 0.00070
# Epoch 86/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 1.2059e-04 - val_loss: 7.6483e-04
#
# Epoch 00086: val_loss did not improve from 0.00070
# Epoch 87/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.1957e-04 - val_loss: 7.3725e-04
#
# Epoch 00087: val_loss did not improve from 0.00070
# Epoch 88/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.1853e-04 - val_loss: 7.1827e-04
#
# Epoch 00088: val_loss did not improve from 0.00070
# Epoch 89/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.1808e-04 - val_loss: 7.4682e-04
#
# Epoch 00089: val_loss did not improve from 0.00070
# Epoch 90/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.1722e-04 - val_loss: 7.8131e-04
#
# Epoch 00090: val_loss did not improve from 0.00070
# Epoch 91/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.1806e-04 - val_loss: 7.3056e-04
#
# Epoch 00091: val_loss did not improve from 0.00070
# Epoch 92/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.1254e-04 - val_loss: 7.0989e-04
#
# Epoch 00092: val_loss did not improve from 0.00070
# Epoch 93/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.1340e-04 - val_loss: 7.0732e-04
#
# Epoch 00093: val_loss did not improve from 0.00070
# Epoch 94/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.1314e-04 - val_loss: 7.3228e-04
#
# Epoch 00094: val_loss did not improve from 0.00070
# Epoch 95/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.1508e-04 - val_loss: 7.1023e-04
#
# Epoch 00095: val_loss did not improve from 0.00070
# Epoch 96/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.1080e-04 - val_loss: 7.2339e-04
#
# Epoch 00096: val_loss did not improve from 0.00070
# Epoch 97/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.1096e-04 - val_loss: 7.4793e-04
#
# Epoch 00097: val_loss did not improve from 0.00070
# Epoch 98/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 1.0992e-04 - val_loss: 7.4751e-04
#
# Epoch 00098: val_loss did not improve from 0.00070
# Epoch 99/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.1231e-04 - val_loss: 7.8597e-04
#
# Epoch 00099: val_loss did not improve from 0.00070
# Epoch 100/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 1.1260e-04 - val_loss: 7.4972e-04
#
# Epoch 00100: val_loss did not improve from 0.00070
# Epoch 101/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.0868e-04 - val_loss: 7.3698e-04
#
# Epoch 00101: val_loss did not improve from 0.00070
# Epoch 102/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.0902e-04 - val_loss: 7.3540e-04
#
# Epoch 00102: val_loss did not improve from 0.00070
# Epoch 103/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 1.0576e-04 - val_loss: 7.2130e-04
#
# Epoch 00103: val_loss did not improve from 0.00070
# Epoch 104/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.0896e-04 - val_loss: 7.1772e-04
#
# Epoch 00104: val_loss did not improve from 0.00070
# Epoch 105/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.0882e-04 - val_loss: 7.2368e-04
#
# Epoch 00105: val_loss did not improve from 0.00070
# Epoch 106/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.0806e-04 - val_loss: 7.3185e-04
#
# Epoch 00106: val_loss did not improve from 0.00070
# Epoch 107/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.0379e-04 - val_loss: 7.3660e-04
#
# Epoch 00107: val_loss did not improve from 0.00070
# Epoch 108/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 1.0663e-04 - val_loss: 7.6201e-04
#
# Epoch 00108: val_loss did not improve from 0.00070
# Epoch 109/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.0419e-04 - val_loss: 6.9525e-04
#
# Epoch 00109: val_loss improved from 0.00070 to 0.00070, saving model to best_weights.h5
# Epoch 110/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 1.0256e-04 - val_loss: 7.3674e-04
#
# Epoch 00110: val_loss did not improve from 0.00070
# Epoch 111/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.0330e-04 - val_loss: 7.4057e-04
#
# Epoch 00111: val_loss did not improve from 0.00070
# Epoch 112/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 1.0075e-04 - val_loss: 7.1505e-04
#
# Epoch 00112: val_loss did not improve from 0.00070
# Epoch 113/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.0468e-04 - val_loss: 7.2118e-04
#
# Epoch 00113: val_loss did not improve from 0.00070
# Epoch 114/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 9.9508e-05 - val_loss: 7.2180e-04
#
# Epoch 00114: val_loss did not improve from 0.00070
# Epoch 115/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 1.0008e-04 - val_loss: 7.1511e-04
#
# Epoch 00115: val_loss did not improve from 0.00070
# Epoch 116/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 9.7206e-05 - val_loss: 7.2477e-04
#
# Epoch 00116: val_loss did not improve from 0.00070
# Epoch 117/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 9.9506e-05 - val_loss: 7.1496e-04
#
# Epoch 00117: val_loss did not improve from 0.00070
# Epoch 118/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 9.9971e-05 - val_loss: 7.2030e-04
#
# Epoch 00118: val_loss did not improve from 0.00070
# Epoch 119/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 9.5450e-05 - val_loss: 7.8650e-04
#
# Epoch 00119: val_loss did not improve from 0.00070
# Epoch 120/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 9.8988e-05 - val_loss: 7.4444e-04
#
# Epoch 00120: val_loss did not improve from 0.00070
# Epoch 121/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 9.7287e-05 - val_loss: 7.5104e-04
#
# Epoch 00121: val_loss did not improve from 0.00070
# Epoch 122/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 9.5179e-05 - val_loss: 7.2108e-04
#
# Epoch 00122: val_loss did not improve from 0.00070
# Epoch 123/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 9.5372e-05 - val_loss: 7.3580e-04
#
# Epoch 00123: val_loss did not improve from 0.00070
# Epoch 124/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 9.3685e-05 - val_loss: 7.3757e-04
#
# Epoch 00124: val_loss did not improve from 0.00070
# Epoch 125/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.5940e-05 - val_loss: 7.2095e-04
#
# Epoch 00125: val_loss did not improve from 0.00070
# Epoch 126/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 9.6705e-05 - val_loss: 7.7853e-04
#
# Epoch 00126: val_loss did not improve from 0.00070
# Epoch 127/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 9.7137e-05 - val_loss: 7.2570e-04
#
# Epoch 00127: val_loss did not improve from 0.00070
# Epoch 128/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 9.3095e-05 - val_loss: 7.5726e-04
#
# Epoch 00128: val_loss did not improve from 0.00070
# Epoch 129/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 9.2793e-05 - val_loss: 7.6238e-04
#
# Epoch 00129: val_loss did not improve from 0.00070
# Epoch 130/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 9.1681e-05 - val_loss: 7.3539e-04
#
# Epoch 00130: val_loss did not improve from 0.00070
# Epoch 131/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 9.2758e-05 - val_loss: 7.3560e-04
#
# Epoch 00131: val_loss did not improve from 0.00070
# Epoch 132/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 8.8176e-05 - val_loss: 7.3925e-04
#
# Epoch 00132: val_loss did not improve from 0.00070
# Epoch 133/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 8.6772e-05 - val_loss: 7.3299e-04
#
# Epoch 00133: val_loss did not improve from 0.00070
# Epoch 134/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 8.8428e-05 - val_loss: 7.2303e-04
#
# Epoch 00134: val_loss did not improve from 0.00070
# Epoch 135/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 8.7348e-05 - val_loss: 7.5128e-04
#
# Epoch 00135: val_loss did not improve from 0.00070
# Epoch 136/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 8.6008e-05 - val_loss: 7.6280e-04
#
# Epoch 00136: val_loss did not improve from 0.00070
# Epoch 137/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 8.6602e-05 - val_loss: 7.2518e-04
#
# Epoch 00137: val_loss did not improve from 0.00070
# Epoch 138/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 8.7623e-05 - val_loss: 7.1582e-04
#
# Epoch 00138: val_loss did not improve from 0.00070
# Epoch 139/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 8.6562e-05 - val_loss: 7.2392e-04
#
# Epoch 00139: val_loss did not improve from 0.00070
# Epoch 140/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 8.7396e-05 - val_loss: 7.3478e-04
#
# Epoch 00140: val_loss did not improve from 0.00070
# Epoch 141/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 8.4561e-05 - val_loss: 8.0374e-04
#
# Epoch 00141: val_loss did not improve from 0.00070
# Epoch 142/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 8.5425e-05 - val_loss: 7.2245e-04
#
# Epoch 00142: val_loss did not improve from 0.00070
# Epoch 143/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 8.7615e-05 - val_loss: 7.7704e-04
#
# Epoch 00143: val_loss did not improve from 0.00070
# Epoch 144/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 8.5739e-05 - val_loss: 7.3312e-04
#
# Epoch 00144: val_loss did not improve from 0.00070
# Epoch 145/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 8.4056e-05 - val_loss: 7.3695e-04
#
# Epoch 00145: val_loss did not improve from 0.00070
# Epoch 146/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 8.3805e-05 - val_loss: 7.5136e-04
#
# Epoch 00146: val_loss did not improve from 0.00070
# Epoch 147/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 8.2187e-05 - val_loss: 7.5071e-04
#
# Epoch 00147: val_loss did not improve from 0.00070
# Epoch 148/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 8.0516e-05 - val_loss: 7.3244e-04
#
# Epoch 00148: val_loss did not improve from 0.00070
# Epoch 149/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 8.1573e-05 - val_loss: 7.5918e-04
#
# Epoch 00149: val_loss did not improve from 0.00070
# Epoch 150/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 8.0903e-05 - val_loss: 7.3523e-04
#
# Epoch 00150: val_loss did not improve from 0.00070

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = '/content/drive/My Drive/AI/1st-DL-CVMarathon/data/facial-keypoints-detection/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 1s 408us/step - loss: 0.0040 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00195, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 187us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00195 to 0.00185, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00185 to 0.00179, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 9.0883e-04 - val_loss: 0.0016
#
# Epoch 00004: val_loss improved from 0.00179 to 0.00163, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 193us/step - loss: 7.1868e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00163 to 0.00123, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 189us/step - loss: 5.7266e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00123 to 0.00108, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 5.0170e-04 - val_loss: 0.0010
#
# Epoch 00007: val_loss improved from 0.00108 to 0.00101, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 196us/step - loss: 4.4269e-04 - val_loss: 9.2563e-04
#
# Epoch 00008: val_loss improved from 0.00101 to 0.00093, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 4.0629e-04 - val_loss: 8.7973e-04
#
# Epoch 00009: val_loss improved from 0.00093 to 0.00088, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 1s 189us/step - loss: 3.7106e-04 - val_loss: 8.4773e-04
#
# Epoch 00010: val_loss improved from 0.00088 to 0.00085, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 3.4753e-04 - val_loss: 7.9415e-04
#
# Epoch 00011: val_loss improved from 0.00085 to 0.00079, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 3.2889e-04 - val_loss: 7.7995e-04
#
# Epoch 00012: val_loss improved from 0.00079 to 0.00078, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 3.1287e-04 - val_loss: 7.5896e-04
#
# Epoch 00013: val_loss improved from 0.00078 to 0.00076, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 2.9608e-04 - val_loss: 7.4457e-04
#
# Epoch 00014: val_loss improved from 0.00076 to 0.00074, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 196us/step - loss: 2.8875e-04 - val_loss: 8.4063e-04
#
# Epoch 00015: val_loss did not improve from 0.00074
# Epoch 16/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 2.7638e-04 - val_loss: 7.2733e-04
#
# Epoch 00016: val_loss improved from 0.00074 to 0.00073, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 2.6351e-04 - val_loss: 7.3637e-04
#
# Epoch 00017: val_loss did not improve from 0.00073
# Epoch 18/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 2.5735e-04 - val_loss: 7.1093e-04
#
# Epoch 00018: val_loss improved from 0.00073 to 0.00071, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 2.5265e-04 - val_loss: 7.2920e-04
#
# Epoch 00019: val_loss did not improve from 0.00071
# Epoch 20/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 2.3625e-04 - val_loss: 6.8934e-04
#
# Epoch 00020: val_loss improved from 0.00071 to 0.00069, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 2.3316e-04 - val_loss: 6.8649e-04
#
# Epoch 00021: val_loss improved from 0.00069 to 0.00069, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 2.3146e-04 - val_loss: 7.3573e-04
#
# Epoch 00022: val_loss did not improve from 0.00069
# Epoch 23/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 2.2129e-04 - val_loss: 6.6810e-04
#
# Epoch 00023: val_loss improved from 0.00069 to 0.00067, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 2.1924e-04 - val_loss: 6.7532e-04
#
# Epoch 00024: val_loss did not improve from 0.00067
# Epoch 25/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 2.0958e-04 - val_loss: 6.6600e-04
#
# Epoch 00025: val_loss improved from 0.00067 to 0.00067, saving model to best_weights_augment.h5
# Epoch 26/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 2.0389e-04 - val_loss: 7.1097e-04
#
# Epoch 00026: val_loss did not improve from 0.00067
# Epoch 27/150
# 3424/3424 [==============================] - 1s 189us/step - loss: 2.0329e-04 - val_loss: 7.3653e-04
#
# Epoch 00027: val_loss did not improve from 0.00067
# Epoch 28/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 2.0232e-04 - val_loss: 6.6779e-04
#
# Epoch 00028: val_loss did not improve from 0.00067
# Epoch 29/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.9243e-04 - val_loss: 6.6942e-04
#
# Epoch 00029: val_loss did not improve from 0.00067
# Epoch 30/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 1.8432e-04 - val_loss: 6.7003e-04
#
# Epoch 00030: val_loss did not improve from 0.00067
# Epoch 31/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 1.8137e-04 - val_loss: 6.5209e-04
#
# Epoch 00031: val_loss improved from 0.00067 to 0.00065, saving model to best_weights_augment.h5
# Epoch 32/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.7404e-04 - val_loss: 6.4291e-04
#
# Epoch 00032: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 1.7323e-04 - val_loss: 6.5819e-04
#
# Epoch 00033: val_loss did not improve from 0.00064
# Epoch 34/150
# 3424/3424 [==============================] - 1s 193us/step - loss: 1.7270e-04 - val_loss: 6.7411e-04
#
# Epoch 00034: val_loss did not improve from 0.00064
# Epoch 35/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 1.6713e-04 - val_loss: 6.5485e-04
#
# Epoch 00035: val_loss did not improve from 0.00064
# Epoch 36/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.6724e-04 - val_loss: 6.9213e-04
#
# Epoch 00036: val_loss did not improve from 0.00064
# Epoch 37/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 1.6633e-04 - val_loss: 6.5695e-04
#
# Epoch 00037: val_loss did not improve from 0.00064
# Epoch 38/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 1.6350e-04 - val_loss: 7.0525e-04
#
# Epoch 00038: val_loss did not improve from 0.00064
# Epoch 39/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 1.6140e-04 - val_loss: 6.5080e-04
#
# Epoch 00039: val_loss did not improve from 0.00064
# Epoch 40/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 1.5273e-04 - val_loss: 6.5682e-04
#
# Epoch 00040: val_loss did not improve from 0.00064
# Epoch 41/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 1.5468e-04 - val_loss: 6.5368e-04
#
# Epoch 00041: val_loss did not improve from 0.00064
# Epoch 42/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 1.5364e-04 - val_loss: 6.7399e-04
#
# Epoch 00042: val_loss did not improve from 0.00064
# Epoch 43/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 1.4957e-04 - val_loss: 6.3719e-04
#
# Epoch 00043: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 44/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 1.5335e-04 - val_loss: 6.4389e-04
#
# Epoch 00044: val_loss did not improve from 0.00064
# Epoch 45/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 1.4737e-04 - val_loss: 6.6854e-04
#
# Epoch 00045: val_loss did not improve from 0.00064
# Epoch 46/150
# 3424/3424 [==============================] - 1s 186us/step - loss: 1.5079e-04 - val_loss: 6.8158e-04
#
# Epoch 00046: val_loss did not improve from 0.00064
# Epoch 47/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.4389e-04 - val_loss: 6.3952e-04
#
# Epoch 00047: val_loss did not improve from 0.00064
# Epoch 48/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 1.3943e-04 - val_loss: 6.4926e-04
#
# Epoch 00048: val_loss did not improve from 0.00064
# Epoch 49/150
# 3424/3424 [==============================] - 1s 186us/step - loss: 1.3613e-04 - val_loss: 6.5846e-04
#
# Epoch 00049: val_loss did not improve from 0.00064
# Epoch 50/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 1.3506e-04 - val_loss: 6.3535e-04
#
# Epoch 00050: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 51/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 1.3499e-04 - val_loss: 6.5072e-04
#
# Epoch 00051: val_loss did not improve from 0.00064
# Epoch 52/150
# 3424/3424 [==============================] - 1s 185us/step - loss: 1.3244e-04 - val_loss: 6.3913e-04
#
# Epoch 00052: val_loss did not improve from 0.00064
# Epoch 53/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 1.3570e-04 - val_loss: 6.8813e-04
#
# Epoch 00053: val_loss did not improve from 0.00064
# Epoch 54/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 1.2830e-04 - val_loss: 6.5455e-04
#
# Epoch 00054: val_loss did not improve from 0.00064
# Epoch 55/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 1.2670e-04 - val_loss: 6.5627e-04
#
# Epoch 00055: val_loss did not improve from 0.00064
# Epoch 56/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 1.2541e-04 - val_loss: 6.8470e-04
#
# Epoch 00056: val_loss did not improve from 0.00064
# Epoch 57/150
# 3424/3424 [==============================] - 1s 188us/step - loss: 1.2601e-04 - val_loss: 6.5598e-04
#
# Epoch 00057: val_loss did not improve from 0.00064
# Epoch 58/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 1.2255e-04 - val_loss: 6.4630e-04
#
# Epoch 00058: val_loss did not improve from 0.00064
# Epoch 59/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 1.2121e-04 - val_loss: 6.4320e-04
#
# Epoch 00059: val_loss did not improve from 0.00064
# Epoch 60/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 1.2054e-04 - val_loss: 6.3935e-04
#
# Epoch 00060: val_loss did not improve from 0.00064
# Epoch 61/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 1.2135e-04 - val_loss: 6.3731e-04
#
# Epoch 00061: val_loss did not improve from 0.00064
# Epoch 62/150
# 3424/3424 [==============================] - 1s 193us/step - loss: 1.2126e-04 - val_loss: 6.5386e-04
#
# Epoch 00062: val_loss did not improve from 0.00064
# Epoch 63/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 1.1788e-04 - val_loss: 6.6098e-04
#
# Epoch 00063: val_loss did not improve from 0.00064
# Epoch 64/150
# 3424/3424 [==============================] - 1s 193us/step - loss: 1.1551e-04 - val_loss: 6.4778e-04
#
# Epoch 00064: val_loss did not improve from 0.00064
# Epoch 65/150
# 3424/3424 [==============================] - 1s 189us/step - loss: 1.1722e-04 - val_loss: 6.7544e-04
#
# Epoch 00065: val_loss did not improve from 0.00064
# Epoch 66/150
# 3424/3424 [==============================] - 1s 188us/step - loss: 1.1548e-04 - val_loss: 6.6017e-04
#
# Epoch 00066: val_loss did not improve from 0.00064
# Epoch 67/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 1.1427e-04 - val_loss: 6.6064e-04
#
# Epoch 00067: val_loss did not improve from 0.00064
# Epoch 68/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 1.1026e-04 - val_loss: 6.7038e-04
#
# Epoch 00068: val_loss did not improve from 0.00064
# Epoch 69/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 1.1054e-04 - val_loss: 6.5545e-04
#
# Epoch 00069: val_loss did not improve from 0.00064
# Epoch 70/150
# 3424/3424 [==============================] - 1s 188us/step - loss: 1.1092e-04 - val_loss: 6.5864e-04
#
# Epoch 00070: val_loss did not improve from 0.00064
# Epoch 71/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 1.0830e-04 - val_loss: 6.7076e-04
#
# Epoch 00071: val_loss did not improve from 0.00064
# Epoch 72/150
# 3424/3424 [==============================] - 1s 187us/step - loss: 1.0823e-04 - val_loss: 6.6786e-04
#
# Epoch 00072: val_loss did not improve from 0.00064
# Epoch 73/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 1.0802e-04 - val_loss: 6.5906e-04
#
# Epoch 00073: val_loss did not improve from 0.00064
# Epoch 74/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 1.0693e-04 - val_loss: 6.7141e-04
#
# Epoch 00074: val_loss did not improve from 0.00064
# Epoch 75/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 1.0350e-04 - val_loss: 6.5860e-04
#
# Epoch 00075: val_loss did not improve from 0.00064
# Epoch 76/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 1.0541e-04 - val_loss: 6.5944e-04
#
# Epoch 00076: val_loss did not improve from 0.00064
# Epoch 77/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 1.0210e-04 - val_loss: 6.3732e-04
#
# Epoch 00077: val_loss did not improve from 0.00064
# Epoch 78/150
# 3424/3424 [==============================] - 1s 188us/step - loss: 1.0416e-04 - val_loss: 6.8565e-04
#
# Epoch 00078: val_loss did not improve from 0.00064
# Epoch 79/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 1.0689e-04 - val_loss: 6.4199e-04
#
# Epoch 00079: val_loss did not improve from 0.00064
# Epoch 80/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 1.0392e-04 - val_loss: 6.7055e-04
#
# Epoch 00080: val_loss did not improve from 0.00064
# Epoch 81/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 1.0089e-04 - val_loss: 6.5396e-04
#
# Epoch 00081: val_loss did not improve from 0.00064
# Epoch 82/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 9.8594e-05 - val_loss: 6.3134e-04
#
# Epoch 00082: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 83/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 9.6497e-05 - val_loss: 6.6258e-04
#
# Epoch 00083: val_loss did not improve from 0.00063
# Epoch 84/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 9.7423e-05 - val_loss: 6.6573e-04
#
# Epoch 00084: val_loss did not improve from 0.00063
# Epoch 85/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 9.6772e-05 - val_loss: 6.5251e-04
#
# Epoch 00085: val_loss did not improve from 0.00063
# Epoch 86/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 9.6561e-05 - val_loss: 6.4036e-04
#
# Epoch 00086: val_loss did not improve from 0.00063
# Epoch 87/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 9.6661e-05 - val_loss: 6.5205e-04
#
# Epoch 00087: val_loss did not improve from 0.00063
# Epoch 88/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 9.7326e-05 - val_loss: 6.6522e-04
#
# Epoch 00088: val_loss did not improve from 0.00063
# Epoch 89/150
# 3424/3424 [==============================] - 1s 196us/step - loss: 9.5910e-05 - val_loss: 6.4808e-04
#
# Epoch 00089: val_loss did not improve from 0.00063
# Epoch 90/150
# 3424/3424 [==============================] - 1s 193us/step - loss: 9.7212e-05 - val_loss: 6.6592e-04
#
# Epoch 00090: val_loss did not improve from 0.00063
# Epoch 91/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 9.4111e-05 - val_loss: 6.4434e-04
#
# Epoch 00091: val_loss did not improve from 0.00063
# Epoch 92/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 9.3332e-05 - val_loss: 6.7286e-04
#
# Epoch 00092: val_loss did not improve from 0.00063
# Epoch 93/150
# 3424/3424 [==============================] - 1s 189us/step - loss: 9.3812e-05 - val_loss: 6.9494e-04
#
# Epoch 00093: val_loss did not improve from 0.00063
# Epoch 94/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 9.4817e-05 - val_loss: 6.3544e-04
#
# Epoch 00094: val_loss did not improve from 0.00063
# Epoch 95/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 9.3822e-05 - val_loss: 6.6046e-04
#
# Epoch 00095: val_loss did not improve from 0.00063
# Epoch 96/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 9.2159e-05 - val_loss: 6.4441e-04
#
# Epoch 00096: val_loss did not improve from 0.00063
# Epoch 97/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 9.0018e-05 - val_loss: 6.3757e-04
#
# Epoch 00097: val_loss did not improve from 0.00063
# Epoch 98/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 9.1744e-05 - val_loss: 6.5368e-04
#
# Epoch 00098: val_loss did not improve from 0.00063
# Epoch 99/150
# 3424/3424 [==============================] - 1s 196us/step - loss: 9.0683e-05 - val_loss: 6.6000e-04
#
# Epoch 00099: val_loss did not improve from 0.00063
# Epoch 100/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 9.0441e-05 - val_loss: 6.4429e-04
#
# Epoch 00100: val_loss did not improve from 0.00063
# Epoch 101/150
# 3424/3424 [==============================] - 1s 185us/step - loss: 8.9505e-05 - val_loss: 6.6023e-04
#
# Epoch 00101: val_loss did not improve from 0.00063
# Epoch 102/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 8.9874e-05 - val_loss: 6.6574e-04
#
# Epoch 00102: val_loss did not improve from 0.00063
# Epoch 103/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 8.8418e-05 - val_loss: 6.4649e-04
#
# Epoch 00103: val_loss did not improve from 0.00063
# Epoch 104/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 8.9368e-05 - val_loss: 6.6444e-04
#
# Epoch 00104: val_loss did not improve from 0.00063
# Epoch 105/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 8.9867e-05 - val_loss: 6.3066e-04
#
# Epoch 00105: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 106/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 8.9374e-05 - val_loss: 6.3721e-04
#
# Epoch 00106: val_loss did not improve from 0.00063
# Epoch 107/150
# 3424/3424 [==============================] - 1s 187us/step - loss: 8.7025e-05 - val_loss: 6.3636e-04
#
# Epoch 00107: val_loss did not improve from 0.00063
# Epoch 108/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 8.6857e-05 - val_loss: 6.5222e-04
#
# Epoch 00108: val_loss did not improve from 0.00063
# Epoch 109/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 8.6489e-05 - val_loss: 6.5240e-04
#
# Epoch 00109: val_loss did not improve from 0.00063
# Epoch 110/150
# 3424/3424 [==============================] - 1s 185us/step - loss: 8.6652e-05 - val_loss: 6.6438e-04
#
# Epoch 00110: val_loss did not improve from 0.00063
# Epoch 111/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 8.4948e-05 - val_loss: 6.5678e-04
#
# Epoch 00111: val_loss did not improve from 0.00063
# Epoch 112/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 8.6083e-05 - val_loss: 6.4636e-04
#
# Epoch 00112: val_loss did not improve from 0.00063
# Epoch 113/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 8.4318e-05 - val_loss: 6.4550e-04
#
# Epoch 00113: val_loss did not improve from 0.00063
# Epoch 114/150
# 3424/3424 [==============================] - 1s 196us/step - loss: 8.6102e-05 - val_loss: 6.6536e-04
#
# Epoch 00114: val_loss did not improve from 0.00063
# Epoch 115/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 8.3528e-05 - val_loss: 6.3939e-04
#
# Epoch 00115: val_loss did not improve from 0.00063
# Epoch 116/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 8.4343e-05 - val_loss: 6.4301e-04
#
# Epoch 00116: val_loss did not improve from 0.00063
# Epoch 117/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 8.3346e-05 - val_loss: 6.4050e-04
#
# Epoch 00117: val_loss did not improve from 0.00063
# Epoch 118/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.4739e-05 - val_loss: 6.5767e-04
#
# Epoch 00118: val_loss did not improve from 0.00063
# Epoch 119/150
# 3424/3424 [==============================] - 1s 186us/step - loss: 8.6786e-05 - val_loss: 6.6937e-04
#
# Epoch 00119: val_loss did not improve from 0.00063
# Epoch 120/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 9.2382e-05 - val_loss: 6.3773e-04
#
# Epoch 00120: val_loss did not improve from 0.00063
# Epoch 121/150
# 3424/3424 [==============================] - 1s 187us/step - loss: 8.5229e-05 - val_loss: 6.3211e-04
#
# Epoch 00121: val_loss did not improve from 0.00063
# Epoch 122/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 8.1566e-05 - val_loss: 6.3529e-04
#
# Epoch 00122: val_loss did not improve from 0.00063
# Epoch 123/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.0679e-05 - val_loss: 6.6101e-04
#
# Epoch 00123: val_loss did not improve from 0.00063
# Epoch 124/150
# 3424/3424 [==============================] - 1s 193us/step - loss: 8.0100e-05 - val_loss: 6.4164e-04
#
# Epoch 00124: val_loss did not improve from 0.00063
# Epoch 125/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 8.0854e-05 - val_loss: 6.4431e-04
#
# Epoch 00125: val_loss did not improve from 0.00063
# Epoch 126/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 8.0582e-05 - val_loss: 6.4007e-04
#
# Epoch 00126: val_loss did not improve from 0.00063
# Epoch 127/150
# 3424/3424 [==============================] - 1s 196us/step - loss: 8.0963e-05 - val_loss: 6.5332e-04
#
# Epoch 00127: val_loss did not improve from 0.00063
# Epoch 128/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 8.0738e-05 - val_loss: 6.3072e-04
#
# Epoch 00128: val_loss did not improve from 0.00063
# Epoch 129/150
# 3424/3424 [==============================] - 1s 188us/step - loss: 7.9834e-05 - val_loss: 6.4066e-04
#
# Epoch 00129: val_loss did not improve from 0.00063
# Epoch 130/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 8.0997e-05 - val_loss: 6.4857e-04
#
# Epoch 00130: val_loss did not improve from 0.00063
# Epoch 131/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 8.0452e-05 - val_loss: 6.4696e-04
#
# Epoch 00131: val_loss did not improve from 0.00063
# Epoch 132/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 7.9773e-05 - val_loss: 6.6000e-04
#
# Epoch 00132: val_loss did not improve from 0.00063
# Epoch 133/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 8.0428e-05 - val_loss: 6.6194e-04
#
# Epoch 00133: val_loss did not improve from 0.00063
# Epoch 134/150
# 3424/3424 [==============================] - 1s 189us/step - loss: 8.0494e-05 - val_loss: 6.4158e-04
#
# Epoch 00134: val_loss did not improve from 0.00063
# Epoch 135/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 7.9774e-05 - val_loss: 6.5618e-04
#
# Epoch 00135: val_loss did not improve from 0.00063
# Epoch 136/150
# 3424/3424 [==============================] - 1s 187us/step - loss: 8.0589e-05 - val_loss: 6.5053e-04
#
# Epoch 00136: val_loss did not improve from 0.00063
# Epoch 137/150
# 3424/3424 [==============================] - 1s 196us/step - loss: 7.8192e-05 - val_loss: 6.5362e-04
#
# Epoch 00137: val_loss did not improve from 0.00063
# Epoch 138/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 7.8767e-05 - val_loss: 6.5628e-04
#
# Epoch 00138: val_loss did not improve from 0.00063
# Epoch 139/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 8.7584e-05 - val_loss: 6.6711e-04
#
# Epoch 00139: val_loss did not improve from 0.00063
# Epoch 140/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 8.4534e-05 - val_loss: 6.9159e-04
#
# Epoch 00140: val_loss did not improve from 0.00063
# Epoch 141/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.1154e-05 - val_loss: 6.5453e-04
#
# Epoch 00141: val_loss did not improve from 0.00063
# Epoch 142/150
# 3424/3424 [==============================] - 1s 190us/step - loss: 7.9682e-05 - val_loss: 6.6312e-04
#
# Epoch 00142: val_loss did not improve from 0.00063
# Epoch 143/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 7.9487e-05 - val_loss: 6.4970e-04
#
# Epoch 00143: val_loss did not improve from 0.00063
# Epoch 144/150
# 3424/3424 [==============================] - 1s 191us/step - loss: 7.6691e-05 - val_loss: 6.3752e-04
#
# Epoch 00144: val_loss did not improve from 0.00063
# Epoch 145/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 7.8607e-05 - val_loss: 6.3075e-04
#
# Epoch 00145: val_loss did not improve from 0.00063
# Epoch 146/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 7.7504e-05 - val_loss: 6.5610e-04
#
# Epoch 00146: val_loss did not improve from 0.00063
# Epoch 147/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 7.6055e-05 - val_loss: 6.2964e-04
#
# Epoch 00147: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 148/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 7.5161e-05 - val_loss: 6.5570e-04
#
# Epoch 00148: val_loss did not improve from 0.00063
# Epoch 149/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 7.6334e-05 - val_loss: 6.7439e-04
#
# Epoch 00149: val_loss did not improve from 0.00063
# Epoch 150/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 7.9313e-05 - val_loss: 6.4703e-04
#
# Epoch 00150: val_loss did not improve from 0.00063

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
